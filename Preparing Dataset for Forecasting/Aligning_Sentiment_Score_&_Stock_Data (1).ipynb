# %%
import pandas as pd
import numpy as np

# %%
stock_df= pd.read_excel(io='/content/Prudential_new.xlsx', sheet_name='Sheet3')

# %%
stock_df
# Out:
#            Date        Close
# 0    2017-01-03  1356.763428
# 1    2017-01-04  1360.076660
# 2    2017-01-05  1326.116089
# 3    2017-01-06  1335.641602
# 4    2017-01-09  1325.287842
# ...         ...          ...
# 1611 2023-05-23  1171.000000
# 1612 2023-05-24  1101.500000
# 1613 2023-05-25  1109.500000
# 1614 2023-05-26  1125.000000
# 1615 2023-05-30  1125.000000
#
# [1616 rows x 2 columns]

# %%
date_range = pd.date_range(start='2017-01-01', end='2023-05-31')

# Create a DataFrame with the complete date range
complete_dates_df = pd.DataFrame(date_range, columns=['Date'])

# Merge the stock data with the complete date range
stock_df = pd.merge(complete_dates_df, stock_df, how='left', on='Date')

# %%
stock_df
# Out:
#            Date        Close
# 0    2017-01-01          NaN
# 1    2017-01-02          NaN
# 2    2017-01-03  1356.763428
# 3    2017-01-04  1360.076660
# 4    2017-01-05  1326.116089
# ...         ...          ...
# 2337 2023-05-27          NaN
# 2338 2023-05-28          NaN
# 2339 2023-05-29          NaN
# 2340 2023-05-30  1125.000000
# 2341 2023-05-31          NaN
#
# [2342 rows x 2 columns]

# %%
sentiment_daily=pd.read_excel('/content/stock_tweets_sentiment(VADER+BERT).xlsx')

# %%
sentiment_daily
# Out:
#            Date  negative   neutral  positive  combined_score
# 0    2017-01-01  0.499988  0.500000  0.000012       -0.499976
# 1    2017-01-02  0.296425  0.544323  0.159126       -0.137299
# 2    2017-01-03  0.441265  0.489222  0.069512       -0.371753
# 3    2017-01-04  0.403945  0.509964  0.086091       -0.317854
# 4    2017-01-05  0.374976  0.423502  0.201521       -0.173455
# ...         ...       ...       ...       ...             ...
# 1975 2023-05-25  0.524454  0.440038  0.035508       -0.488945
# 1976 2023-05-26  0.387832  0.502415  0.109754       -0.278078
# 1977 2023-05-28  0.615427  0.384504  0.000070       -0.615357
# 1978 2023-05-30  0.250000  0.698750  0.051250       -0.198750
# 1979 2023-05-31  0.381686  0.500024  0.118290       -0.263396
#
# [1980 rows x 5 columns]

# %%
sentiment_daily['Date'] = pd.to_datetime(sentiment_daily['Date'])
stock_df['Date'] = pd.to_datetime(stock_df['Date'])

# Merge the dataframes, only including the 'combined_score' column from sentiment_daily
merged_df = pd.merge(stock_df, sentiment_daily[['Date','negative','neutral', 'positive', 'combined_score']], how='left', left_on='Date', right_on='Date')

# %%
merged_df
# Out:
#            Date        Close  negative   neutral  positive  combined_score
# 0    2017-01-01          NaN  0.499988  0.500000  0.000012       -0.499976
# 1    2017-01-02          NaN  0.296425  0.544323  0.159126       -0.137299
# 2    2017-01-03  1356.763428  0.441265  0.489222  0.069512       -0.371753
# 3    2017-01-04  1360.076660  0.403945  0.509964  0.086091       -0.317854
# 4    2017-01-05  1326.116089  0.374976  0.423502  0.201521       -0.173455
# ...         ...          ...       ...       ...       ...             ...
# 2337 2023-05-27          NaN       NaN       NaN       NaN             NaN
# 2338 2023-05-28          NaN  0.615427  0.384504  0.000070       -0.615357
# 2339 2023-05-29          NaN       NaN       NaN       NaN             NaN
# 2340 2023-05-30  1125.000000  0.250000  0.698750  0.051250       -0.198750
# 2341 2023-05-31          NaN  0.381686  0.500024  0.118290       -0.263396
#
# [2342 rows x 6 columns]

# %%
df_cleaned = merged_df.dropna(subset=['Close', 'combined_score'], how='all')
df_cleaned = df_cleaned.dropna(subset=['negative', 'neutral', 'positive'], how='all')

# %%
df_cleaned
# Out:
#            Date        Close  negative   neutral  positive  combined_score
# 0    2017-01-01          NaN  0.499988  0.500000  0.000012       -0.499976
# 1    2017-01-02          NaN  0.296425  0.544323  0.159126       -0.137299
# 2    2017-01-03  1356.763428  0.441265  0.489222  0.069512       -0.371753
# 3    2017-01-04  1360.076660  0.403945  0.509964  0.086091       -0.317854
# 4    2017-01-05  1326.116089  0.374976  0.423502  0.201521       -0.173455
# ...         ...          ...       ...       ...       ...             ...
# 2335 2023-05-25  1109.500000  0.524454  0.440038  0.035508       -0.488945
# 2336 2023-05-26  1125.000000  0.387832  0.502415  0.109754       -0.278078
# 2338 2023-05-28          NaN  0.615427  0.384504  0.000070       -0.615357
# 2340 2023-05-30  1125.000000  0.250000  0.698750  0.051250       -0.198750
# 2341 2023-05-31          NaN  0.381686  0.500024  0.118290       -0.263396
#
# [1980 rows x 6 columns]

# %%
df_cleaned['Close'] = df_cleaned['Close'].fillna(method='ffill')

# %%
df_cleaned
# Out:
#            Date        Close  negative   neutral  positive  combined_score
# 0    2017-01-01          NaN  0.499988  0.500000  0.000012       -0.499976
# 1    2017-01-02          NaN  0.296425  0.544323  0.159126       -0.137299
# 2    2017-01-03  1356.763428  0.441265  0.489222  0.069512       -0.371753
# 3    2017-01-04  1360.076660  0.403945  0.509964  0.086091       -0.317854
# 4    2017-01-05  1326.116089  0.374976  0.423502  0.201521       -0.173455
# ...         ...          ...       ...       ...       ...             ...
# 2335 2023-05-25  1109.500000  0.524454  0.440038  0.035508       -0.488945
# 2336 2023-05-26  1125.000000  0.387832  0.502415  0.109754       -0.278078
# 2338 2023-05-28  1125.000000  0.615427  0.384504  0.000070       -0.615357
# 2340 2023-05-30  1125.000000  0.250000  0.698750  0.051250       -0.198750
# 2341 2023-05-31  1125.000000  0.381686  0.500024  0.118290       -0.263396
#
# [1980 rows x 6 columns]

# %%
df_cleaned['Close'] = df_cleaned['Close'].fillna(method='bfill')

# %%
df_cleaned
# Out:
#            Date        Close  negative   neutral  positive  combined_score
# 0    2017-01-01  1356.763428  0.499988  0.500000  0.000012       -0.499976
# 1    2017-01-02  1356.763428  0.296425  0.544323  0.159126       -0.137299
# 2    2017-01-03  1356.763428  0.441265  0.489222  0.069512       -0.371753
# 3    2017-01-04  1360.076660  0.403945  0.509964  0.086091       -0.317854
# 4    2017-01-05  1326.116089  0.374976  0.423502  0.201521       -0.173455
# ...         ...          ...       ...       ...       ...             ...
# 2335 2023-05-25  1109.500000  0.524454  0.440038  0.035508       -0.488945
# 2336 2023-05-26  1125.000000  0.387832  0.502415  0.109754       -0.278078
# 2338 2023-05-28  1125.000000  0.615427  0.384504  0.000070       -0.615357
# 2340 2023-05-30  1125.000000  0.250000  0.698750  0.051250       -0.198750
# 2341 2023-05-31  1125.000000  0.381686  0.500024  0.118290       -0.263396
#
# [1980 rows x 6 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1980 entries, 0 to 2341
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1980 non-null   datetime64[ns]
#  1   Close           1980 non-null   float64
#  2   negative        1980 non-null   float64
#  3   neutral         1980 non-null   float64
#  4   positive        1980 non-null   float64
#  5   combined_score  1980 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 108.3 KB

# %%
df_cleaned.to_excel('Stock_Forecasting_data(VADER+BERT).xlsx', index=False)
