# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/content/Cashtags_2017-2023.xlsx')

# %%
# Filter tweets mentioning Prudential
stock_tweets = df[df['tweet'].str.contains('Prudential|$PRU', case=False, na=False)]

#Renaming 'created_at' to 'Date'
stock_tweets.rename(columns={'created_at': 'Date'}, inplace=True)

stock_tweets['Date'] = pd.to_datetime(stock_tweets['Date'])

#Extract date part
stock_tweets['Date'] = stock_tweets['Date'].dt.date
# Out:
# <ipython-input-3-7b022606555b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets.rename(columns={'created_at': 'Date'}, inplace=True)
# <ipython-input-3-7b022606555b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets['Date'] = pd.to_datetime(stock_tweets['Date'])
# <ipython-input-3-7b022606555b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Dropping unnecesary columns

stock_tweets.drop(['author id','id','lang'], axis=1, inplace=True)
# Out:
# <ipython-input-4-f07e51a1f46c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets.drop(['author id','id','lang'], axis=1, inplace=True)

# %%
import re
import string
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Preprocess tweet text
def preprocess_tweet(tweet):
    # Convert to lowercase
    tweet = tweet.lower()

    # Remove special characters
    tweet = re.sub(r'[^\w\s]', '', tweet)

    # Remove URLs
    tweet = re.sub(r'http\S+', '', tweet)
    tweet = re.sub(r'www\S+', '', tweet)

    # Remove hashtags and user mentions
    tweet = re.sub(r'#\w+', '', tweet)
    tweet = re.sub(r'@\w+', '', tweet)

    # Remove punctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))

    # Tokenization
    tokens = word_tokenize(tweet)

    # Remove stop words
    tokens = [token for token in tokens if token not in stopwords.words('english')]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    return ' '.join(tokens)

# Apply preprocessing
tweets = [preprocess_tweet(tweet) for tweet in stock_tweets['tweet']]

# %%
stock_tweets['cleaned_tweet'] = tweets
stock_tweets
# Out:
# <ipython-input-7-cf883bd8d80d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets['cleaned_tweet'] = tweets
#               Date                                              tweet  \
# 8       2017-01-01  Henderson Group PLC Has $4,519,000 Stake in Pr...
# 29      2017-01-02  Prudential Financial, Inc. $PRU Rating Lowered...
# 42      2017-01-02  King Luther Capital Management Corp Sells 7,27...
# 43      2017-01-02  King Luther Capital Management Corp Sells 7,27...
# 49      2017-01-02  #PrudentialFinancial Inc. Cuts Position in AG ...
# ...            ...                                                ...
# 395791  2023-05-31  Prudential plc $PRU has dipped $-69 (-6.13%) n...
# ...

# %%
#Removing duplicates
stock_tweets.drop_duplicates(subset=['cleaned_tweet'], inplace = True)
# Out:
# <ipython-input-8-e58614a5f446>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets.drop_duplicates(subset=['cleaned_tweet'], inplace = True)

# %%
stock_tweets
# Out:
#               Date                                              tweet  \
# 8       2017-01-01  Henderson Group PLC Has $4,519,000 Stake in Pr...
# 29      2017-01-02  Prudential Financial, Inc. $PRU Rating Lowered...
# 42      2017-01-02  King Luther Capital Management Corp Sells 7,27...
# 49      2017-01-02  #PrudentialFinancial Inc. Cuts Position in AG ...
# 52      2017-01-02  #PrudentialFinancial, Inc. Given "Buy" Rating ...
# ...            ...                                                ...
# 393764  2023-05-31  $PRU Prudential's CFO quits after code of cond...
# 395104  2023-05-31  $PRU - Prudential's CFO quits after code of co...
# 395750  2023-05-31  Prudential plc $PRU has dipped $-60 (-5.33%) n...
# 395762  2023-05-31  Prudential plc $PRU has dipped $-67.5 (-6%) no...
# 395780  2023-05-31  Prudential plc $PRU has dipped $-69 (-6.13%) n...
#
#                                             cleaned_tweet
# 8       henderson group plc 4519000 stake prudential f...
# ...

# %%
! pip install -q vaderSentiment
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 4.5 MB/s eta 0:00:00

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# Download the VADER lexicon
nltk.download('vader_lexicon')

# Initialize VADER SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# Define a function to get the sentiment scores
def get_vader_sentiment(text):
    return sid.polarity_scores(text)

# Apply the function and extract sentiment scores into separate columns
stock_tweets['neg'] = stock_tweets['cleaned_tweet'].apply(lambda x: get_vader_sentiment(x)['neg'])
stock_tweets['neu'] = stock_tweets['cleaned_tweet'].apply(lambda x: get_vader_sentiment(x)['neu'])
stock_tweets['pos'] = stock_tweets['cleaned_tweet'].apply(lambda x: get_vader_sentiment(x)['pos'])
# stock_tweets['compound'] = stock_tweets['cleaned_tweet'].apply(lambda x: get_vader_sentiment(x)['compound'])
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# <ipython-input-11-b2d6b25afdc0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets['neg'] = stock_tweets['cleaned_tweet'].apply(lambda x: get_vader_sentiment(x)['neg'])
# <ipython-input-11-b2d6b25afdc0>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets['neu'] = stock_tweets['cleaned_tweet'].apply(lambda x: get_vader_sentiment(x)['neu'])
# ...

# %%
stock_tweets
# Out:
#               Date                                              tweet  \
# 8       2017-01-01  Henderson Group PLC Has $4,519,000 Stake in Pr...
# 29      2017-01-02  Prudential Financial, Inc. $PRU Rating Lowered...
# 42      2017-01-02  King Luther Capital Management Corp Sells 7,27...
# 49      2017-01-02  #PrudentialFinancial Inc. Cuts Position in AG ...
# 52      2017-01-02  #PrudentialFinancial, Inc. Given "Buy" Rating ...
# ...            ...                                                ...
# 393764  2023-05-31  $PRU Prudential's CFO quits after code of cond...
# 395104  2023-05-31  $PRU - Prudential's CFO quits after code of co...
# 395750  2023-05-31  Prudential plc $PRU has dipped $-60 (-5.33%) n...
# 395762  2023-05-31  Prudential plc $PRU has dipped $-67.5 (-6%) no...
# 395780  2023-05-31  Prudential plc $PRU has dipped $-69 (-6.13%) n...
#
#                                             cleaned_tweet    neg    neu    pos
# ...

# %%
def combined_sentiment_score(row):
    positive_score = row['pos']
    negative_score = row['neg']
    neutral_score = row['neu']

    combined_score = positive_score - negative_score

    return combined_score

# Apply the function to each row to get the combined sentiment score
stock_tweets['combined_score'] = stock_tweets.apply(combined_sentiment_score, axis=1)
# Out:
# <ipython-input-13-dddbffe3c97a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets['combined_score'] = stock_tweets.apply(combined_sentiment_score, axis=1)

# %%
stock_tweets.drop(columns=['tweet','cleaned_tweet'], inplace=True)
# Out:
# <ipython-input-14-bf6d5f3bf021>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets.drop(columns=['tweet','cleaned_tweet'], inplace=True)

# %%
stock_tweets.head(50)
# Out:
#            Date    neg    neu    pos  combined_score
# 8    2017-01-01  0.000  1.000  0.000           0.000
# 29   2017-01-02  0.143  0.857  0.000          -0.143
# 42   2017-01-02  0.000  0.833  0.167           0.167
# 49   2017-01-02  0.136  0.649  0.214           0.078
# 52   2017-01-02  0.000  1.000  0.000           0.000
# 65   2017-01-03  0.000  0.761  0.239           0.239
# 68   2017-01-03  0.000  1.000  0.000           0.000
# 81   2017-01-03  0.000  1.000  0.000           0.000
# 83   2017-01-03  0.000  1.000  0.000           0.000
# 105  2017-01-03  0.231  0.769  0.000          -0.231
# 144  2017-01-03  0.000  0.694  0.306           0.306
# 145  2017-01-03  0.000  0.621  0.379           0.379
# 169  2017-01-04  0.000  0.762  0.238           0.238
# 177  2017-01-04  0.000  0.820  0.180           0.180
# 181  2017-01-04  0.000  0.820  0.180           0.180
# 221  2017-01-04  0.000  0.796  0.204           0.204
# 222  2017-01-04  0.000  0.581  0.419           0.419
# ...

# %%
stock_tweets.rename(columns={'neg': 'negative', 'pos':'positive', 'neu':'neutral', 'compound':'combined_score'}, inplace=True)
# Out:
# <ipython-input-16-e30ae641b8d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_tweets.rename(columns={'neg': 'negative', 'pos':'positive', 'neu':'neutral', 'compound':'combined_score'}, inplace=True)

# %%
stock_tweets
# Out:
#               Date  negative  neutral  positive  combined_score
# 8       2017-01-01     0.000    1.000     0.000           0.000
# 29      2017-01-02     0.143    0.857     0.000          -0.143
# 42      2017-01-02     0.000    0.833     0.167           0.167
# 49      2017-01-02     0.136    0.649     0.214           0.078
# 52      2017-01-02     0.000    1.000     0.000           0.000
# ...            ...       ...      ...       ...             ...
# 393764  2023-05-31     0.000    1.000     0.000           0.000
# 395104  2023-05-31     0.000    1.000     0.000           0.000
# 395750  2023-05-31     0.000    1.000     0.000           0.000
# 395762  2023-05-31     0.000    1.000     0.000           0.000
# 395780  2023-05-31     0.000    1.000     0.000           0.000
#
# [9649 rows x 5 columns]

# %%
# Group by 'Date' and calculate the mean for 'negative', 'neutral', and 'positive'
stock_tweets_sentiment = stock_tweets.groupby('Date').agg({
    'negative': 'mean',
    'neutral': 'mean',
    'positive': 'mean',
    'combined_score': 'mean'
}).reset_index()

# %%
stock_tweets_sentiment
# Out:
#             Date  negative  neutral  positive  combined_score
# 0     2017-01-01   0.00000  1.00000   0.00000          0.0000
# 1     2017-01-02   0.06975  0.83475   0.09525          0.0255
# 2     2017-01-03   0.03300  0.83500   0.13200          0.0990
# 3     2017-01-04   0.00000  0.82800   0.17200          0.1720
# 4     2017-01-05   0.00000  0.84700   0.15300          0.1530
# ...          ...       ...      ...       ...             ...
# 1975  2023-05-25   0.04900  0.87850   0.07250          0.0235
# 1976  2023-05-26   0.00000  1.00000   0.00000          0.0000
# 1977  2023-05-28   0.23100  0.76900   0.00000         -0.2310
# 1978  2023-05-30   0.00000  0.89750   0.10250          0.1025
# 1979  2023-05-31   0.00000  1.00000   0.00000          0.0000
#
# [1980 rows x 5 columns]

# %%
stock_tweets_sentiment.to_excel('stock_tweets_sentiment(VADER).xlsx', index=False)
